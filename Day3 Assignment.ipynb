# %% [markdown]
# # Day3 Assignment

# %%
## Assignment - Explore this dataset using pandas...

# %%
import pandas as pd

# %%
df=pd.read_csv('https://download.bls.gov/pub/time.series/cu/cu.item',
                 sep='\t')

# %%
df
# Out:
#     item_code                                          item_name  \
# 0         AA0                               All items - old base
# 1        AA0R  Purchasing power of the consumer dollar - old ...
# 2         SA0                                          All items
# 3        SA0E                                             Energy
# 4       SA0L1                                All items less food
# ..        ...                                                ...
# 394   SS68023   Tax return preparation and other accounting fees
# 395   SSEA011                                  College textbooks
# 396  SSFV031A           Food at elementary and secondary schools
# 397   SSGE013                                 Infants' equipment
# 398   SSHJ031                                 Infants' furniture
#
#      display_level selectable  sort_sequence
# 0                0          T              2
# 1                0          T            399
# 2                0          T              1
# ...

# %%
df.head()
# Out:
#   item_code                                          item_name  display_level  \
# 0       AA0                               All items - old base              0
# 1      AA0R  Purchasing power of the consumer dollar - old ...              0
# 2       SA0                                          All items              0
# 3      SA0E                                             Energy              1
# 4     SA0L1                                All items less food              1
#
#   selectable  sort_sequence
# 0          T              2
# 1          T            399
# 2          T              1
# 3          T            374
# 4          T            358

# %%
df[["item_name", "item_code"]]
# Out:
#                                              item_name item_code
# 0                                 All items - old base       AA0
# 1    Purchasing power of the consumer dollar - old ...      AA0R
# 2                                            All items       SA0
# 3                                               Energy      SA0E
# 4                                  All items less food     SA0L1
# ..                                                 ...       ...
# 394   Tax return preparation and other accounting fees   SS68023
# 395                                  College textbooks   SSEA011
# 396           Food at elementary and secondary schools  SSFV031A
# 397                                 Infants' equipment   SSGE013
# 398                                 Infants' furniture   SSHJ031
#
# [399 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   item_code      399 non-null    object
#  1   item_name      399 non-null    object
#  2   display_level  399 non-null    int64
#  3   selectable     399 non-null    object
#  4   sort_sequence  399 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 15.7+ KB

# %%
df.describe()
# Out:
#        display_level  sort_sequence
# count     399.000000     399.000000
# mean        3.192982     200.000000
# std         1.817102     115.325626
# min         0.000000       1.000000
# 25%         2.000000     100.500000
# 50%         3.000000     200.000000
# 75%         4.000000     299.500000
# max         8.000000     399.000000

# %%
df.iloc[1:,:3]
# Out:
#     item_code                                          item_name  \
# 1        AA0R  Purchasing power of the consumer dollar - old ...
# 2         SA0                                          All items
# 3        SA0E                                             Energy
# 4       SA0L1                                All items less food
# 5      SA0L12                    All items less food and shelter
# ..        ...                                                ...
# 394   SS68023   Tax return preparation and other accounting fees
# 395   SSEA011                                  College textbooks
# 396  SSFV031A           Food at elementary and secondary schools
# 397   SSGE013                                 Infants' equipment
# 398   SSHJ031                                 Infants' furniture
#
#      display_level
# 1                0
# 2                0
# 3                1
# 4                1
# 5                1
# ..             ...
# 394              4
# 395              3
# ...

# %%
df.iloc[:,:].values
# Out:
# array([['AA0', 'All items - old base', 0, 'T', 2],
#        ['AA0R', 'Purchasing power of the consumer dollar - old base', 0,
#         'T', 399],
#        ['SA0', 'All items', 0, 'T', 1],
#        ...,
#        ['SSFV031A', 'Food at elementary and secondary schools', 3, 'T',
#         122],
#        ['SSGE013', "Infants' equipment", 3, 'T', 355],
#        ['SSHJ031', "Infants' furniture", 3, 'T', 165]], dtype=object)

# %%
df["display_level"].value_counts()
# Out:
# 3    113
# 2     70
# 1     66
# 4     43
# 6     37
# 5     37
# 7     18
# 0     12
# 8      3
# Name: display_level, dtype: int64

# %%
df.isnull().sum()
# Out:
# item_code        0
# item_name        0
# display_level    0
# selectable       0
# sort_sequence    0
# dtype: int64

# %%
df["item_name"].unique()
# Out:
# array(['All items - old base',
#        'Purchasing power of the consumer dollar - old base', 'All items',
#        'Energy', 'All items less food', 'All items less food and shelter',
#        'All items less food, shelter, and energy',
#        'All items less food, shelter, energy, and used cars and trucks',
#        'All items less food and energy', 'All items less shelter',
#        'All items less medical care', 'All items less energy',
#        'Purchasing power of the consumer dollar', 'Apparel less footwear',
#        'Apparel', "Men's and boys' apparel", "Women's and girls' apparel",
#        'Commodities', 'Energy commodities', 'Commodities less food',
#        'Commodities less food and beverages',
#        'Commodities less food and energy commodities',
#        'Commodities less food, energy, and used cars and trucks',
#        'Durables', 'Education and communication', 'Education',
#        'Communication', 'Information and information processing',
# ...
